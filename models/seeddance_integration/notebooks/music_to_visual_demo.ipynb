# %% [markdown]
# # Music To Visual Demo
#
# This notebook demonstrates how analysis tags can be translated into visual prompts.

# %% [markdown]
# ## Planned Outputs
#
# - Music feature tags
# - Visual prompt templates
# - Example rendered scene descriptions

# %%
style_tags = ['印象派', '抒情']
mood_tags = ['平静', '温暖']
visual_prompt = (
    f'以{style_tags[0]}风格构建教学场景，用流动的色彩呈现{mood_tags[0]}与{mood_tags[1]}，'
    '并展示原曲与重构曲的并置比较。'
)
visual_prompt
