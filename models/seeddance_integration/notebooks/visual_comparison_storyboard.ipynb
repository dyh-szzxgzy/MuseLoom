# %% [markdown]
# # Visual Comparison Storyboard
#
# This notebook frames how original and regenerated music can be compared through visual descriptions.

# %% [markdown]
# ## Comparison Logic
#
# - original music prompt
# - regenerated music prompt
# - visual contrast notes for classroom explanation

# %%
storyboard = {
    'original': '柔和、克制、层次细腻的教室视觉场景',
    'regenerated': '色彩更温暖、构图更开放的课堂舞台场景',
    'teaching_note': '用于帮助学生理解风格重构如何影响审美联想。'
}
storyboard
