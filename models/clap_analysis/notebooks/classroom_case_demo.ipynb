# %% [markdown]
# # Classroom Case Demo
#
# This notebook presents a sample classroom walkthrough for the MuseLoom analysis module.

# %% [markdown]
# ## Scenario
#
# A teacher uploads a lyrical piano excerpt and asks students to compare its emotional profile before and after style transfer.

# %%
case_input = {
    'audio_name': 'sample_audio.wav',
    'classroom_context': '高中音乐鉴赏课'
}
case_input

# %%
case_output = {
    'style_tags': ['印象派', '室内乐', '抒情'],
    'mood_tags': ['平静', '温暖', '沉思'],
    'teaching_hint': '适合用于课堂中的风格迁移和情绪表达分析。'
}
case_output
