# %% [markdown]
# # Dataset Overview
#
# This notebook explains the planned structure of the teaching-oriented music dataset.

# %% [markdown]
# ## Sections
#
# - Dataset schema
# - Sample metadata
# - Label distribution and teaching use cases

# %%
import json
import pandas as pd
from pathlib import Path

df = pd.read_csv('../dataset/metadata_example.csv')
df

# %%
manifest_path = Path('../dataset/train_manifest.jsonl')
records = [json.loads(line) for line in manifest_path.read_text(encoding='utf-8').splitlines()]
records
